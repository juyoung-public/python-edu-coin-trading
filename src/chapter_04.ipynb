# %%
# 3. 시세 데이터 가져오기 (Pandas)
import pybithumb
import pandas as pd

df = pybithumb.get_ohlcv("BTC")
df.head()
# Out:
#                    open         high          low        close      volume
# time
# 2026-01-13  134030000.0  136620000.0  133738000.0  136163000.0  550.537513
# 2026-01-14  136163000.0  141728000.0  135704000.0  141268000.0  934.413241
# 2026-01-15  141214000.0  143100000.0  140666000.0  141263000.0  792.313350
# 2026-01-16  141242000.0  142602000.0  140204000.0  140615000.0  423.638181
# 2026-01-17  140600000.0  141198000.0  139770000.0  140857000.0  256.653002

# %%
# 4. 시세 데이터 시각화 (Matplotlib)
import matplotlib.pyplot as plt

# 그래프의 크기 설정 (가로 10, 세로 5)
plt.figure(figsize=(10, 5))

# 종가(close) 데이터를 그래프로 그리기
plt.plot(df.index, df['close'], label='BTC Close Price', color='orange')

# 그래프 꾸미기 (한글 폰트 설정이 안 되어 있을 경우 영어 권장)
plt.title('Bitcoin Price Chart') # 제목
plt.xlabel('Date')               # x축 이름
plt.ylabel('Price (KRW)')        # y축 이름
plt.legend()                     # 범례 표시
plt.grid(True)                   # 격자 표시

# 화면에 출력
plt.show()

# %%
# 5. 시세 데이터 분석 (Pandas)
# 5일 이동평균선 계산 (5일간의 평균 가격)
df['MA'] = df['close'].rolling(window=5).mean()

plt.figure(figsize=(10, 5))

# 실제 종가 그래프
plt.plot(df.index, df['close'], label='Close Price')

# 5일 이동평균선 그래프 (빨간색 점선)
plt.plot(df.index, df['MA'], label='Moving Average', color='red', linestyle='--')

plt.title('Bitcoin Price with Moving Average')
plt.legend()
plt.show()
